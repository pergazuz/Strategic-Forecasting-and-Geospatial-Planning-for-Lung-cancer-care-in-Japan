# %% [markdown]
# ## Import lib

# %%
import geopandas as gpd
import pandas as pd
import folium
import mapclassify
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import japan shp map

# %%
japan_shp = gpd.read_file('gadm41_JPN_shp/gadm41_JPN_1.shp')
japan_shp
# Out:
#        GID_1 GID_0 COUNTRY     NAME_1              VARNAME_1 NL_NAME_1 TYPE_1  \
# 0    JPN.1_1   JPN   Japan      Aichi                   Aiti       愛知県    Ken
# 1    JPN.2_1   JPN   Japan      Akita                     NA       秋田県    Ken
# 2    JPN.3_1   JPN   Japan     Aomori                     NA       青森県    Ken
# 3    JPN.4_1   JPN   Japan      Chiba             Tiba|Tsiba       千葉県    Ken
# 4    JPN.5_1   JPN   Japan      Ehime                     NA       愛媛県    Ken
# 5    JPN.6_1   JPN   Japan      Fukui                  Hukui       福井県    Ken
# 6    JPN.7_1   JPN   Japan    Fukuoka                Hukuoka       福岡県    Ken
# 7    JPN.8_1   JPN   Japan  Fukushima               Hukusima       福島県    Ken
# 8    JPN.9_1   JPN   Japan       Gifu                   Gihu       岐阜県    Ken
# 9   JPN.10_1   JPN   Japan      Gunma             GunmaGumma       群馬県    Ken
# 10  JPN.11_1   JPN   Japan  Hiroshima               Hirosima       広島県    Ken
# 11  JPN.12_1   JPN   Japan   Hokkaido          Ezo|Yeso|Yezo       北海道     Do
# 12  JPN.13_1   JPN   Japan      Hyōgo                  Hiogo       兵庫県    Ken
# 13  JPN.14_1   JPN   Japan    Ibaraki                     NA       茨城県    Ken
# 14  JPN.15_1   JPN   Japan   Ishikawa                Isikawa       石川県    Ken
# 15  JPN.16_1   JPN   Japan      Iwate                     NA       岩手県    Ken
# 16  JPN.17_1   JPN   Japan     Kagawa                     NA       香川県    Ken
# 17  JPN.18_1   JPN   Japan  Kagoshima                     NA      鹿児島県    Ken
# 18  JPN.19_1   JPN   Japan   Kanagawa                     NA      神奈川県    Ken
# 19  JPN.20_1   JPN   Japan      Kochi                   Koti       高知県    Ken
# 20  JPN.21_1   JPN   Japan   Kumamoto                     NA       熊本県    Ken
# 21  JPN.22_1   JPN   Japan      Kyoto                  Kioto       京都府     Fu
# 22  JPN.23_1   JPN   Japan        Mie                   Miye       三重県    Ken
# 23  JPN.24_1   JPN   Japan     Miyagi                     NA       宮城県    Ken
# 24  JPN.25_1   JPN   Japan   Miyazaki                     NA       宮崎県    Ken
# 25  JPN.26_1   JPN   Japan     Nagano                     NA       長野県    Ken
# 26  JPN.27_1   JPN   Japan   Naoasaki               Nagasaki       長崎県    Ken
# 27  JPN.28_1   JPN   Japan       Nara                     NA       奈良県    Ken
# 28  JPN.29_1   JPN   Japan    Niigata                     NA       新潟県    Ken
# 29  JPN.30_1   JPN   Japan       Oita                     NA       大分県    Ken
# 30  JPN.31_1   JPN   Japan    Okayama                     NA       岡山県    Ken
# 31  JPN.32_1   JPN   Japan    Okinawa                     NA       沖縄県    Ken
# 32  JPN.33_1   JPN   Japan      Osaka                     NA       大阪府     Fu
# 33  JPN.34_1   JPN   Japan       Saga                     NA       佐賀県    Ken
# 34  JPN.35_1   JPN   Japan    Saitama                     NA       埼玉県    Ken
# 35  JPN.36_1   JPN   Japan      Shiga                   Siga       滋賀県    Ken
# 36  JPN.37_1   JPN   Japan    Shimane                 Simane       島根県    Ken
# 37  JPN.38_1   JPN   Japan   Shizuoka                Sizuoka       静岡県    Ken
# 38  JPN.39_1   JPN   Japan    Tochigi                 Totigi       栃木県    Ken
# 39  JPN.40_1   JPN   Japan  Tokushima               Tokusima       徳島県    Ken
# 40  JPN.41_1   JPN   Japan      Tokyo  Edo|Yedo|Tokio|T¢quio       東京都     To
# 41  JPN.42_1   JPN   Japan    Tottori                     NA       鳥取県    Ken
# 42  JPN.43_1   JPN   Japan     Toyama                     NA       富山県    Ken
# 43  JPN.44_1   JPN   Japan   Wakayama                     NA      和歌山県    Ken
# 44  JPN.45_1   JPN   Japan   Yamagata                     NA       山形県    Ken
# 45  JPN.46_1   JPN   Japan  Yamaguchi               Yamaguti       山口県    Ken
# 46  JPN.47_1   JPN   Japan  Yamanashi               Yamanasi       山梨県    Ken
#
#            ENGTYPE_1 CC_1 HASC_1  ISO_1  \
# 0         Prefecture   NA  JP.AI  JP-23
# 1         Prefecture   NA  JP.AK  JP-05
# 2         Prefecture   NA  JP.AO  JP-02
# 3         Prefecture   NA  JP.CH  JP-12
# 4         Prefecture   NA  JP.EH  JP-38
# 5         Prefecture   NA  JP.FI  JP-18
# 6         Prefecture   NA  JP.FO  JP-40
# 7         Prefecture   NA  JP.FS  JP-07
# 8         Prefecture   NA  JP.GF  JP-21
# 9         Prefecture   NA  JP.GM  JP-10
# 10        Prefecture   NA  JP.HS  JP-34
# 11           Circuit   NA  JP.HK  JP-01
# 12        Prefecture   NA  JP.HG     NA
# 13        Prefecture   NA  JP.IB  JP-08
# 14        Prefecture   NA  JP.IS  JP-17
# 15        Prefecture   NA  JP.IW  JP-03
# 16        Prefecture   NA  JP.KG  JP-37
# 17        Prefecture   NA  JP.KS  JP-46
# 18        Prefecture   NA  JP.KN  JP-14
# 19        Prefecture   NA  JP.KC  JP-39
# 20        Prefecture   NA  JP.KM  JP-43
# 21  Urban Prefecture   NA  JP.KY  JP-26
# 22        Prefecture   NA  JP.ME  JP-24
# 23        Prefecture   NA  JP.MG  JP-04
# 24        Prefecture   NA  JP.MZ  JP-45
# 25        Prefecture   NA  JP.NN  JP-20
# 26        Prefecture   NA  JP.NS     NA
# 27        Prefecture   NA  JP.NR  JP-29
# 28        Prefecture   NA  JP.NI  JP-15
# 29        Prefecture   NA  JP.OT  JP-44
# 30        Prefecture   NA  JP.OY  JP-33
# 31        Prefecture   NA  JP.ON  JP-47
# 32  Urban Prefecture   NA  JP.OS  JP-27
# 33        Prefecture   NA  JP.SG  JP-41
# 34        Prefecture   NA  JP.ST  JP-11
# 35        Prefecture   NA  JP.SH  JP-25
# 36        Prefecture   NA  JP.SM  JP-32
# 37        Prefecture   NA  JP.SZ  JP-22
# 38        Prefecture   NA  JP.TC  JP-09
# 39        Prefecture   NA  JP.TS  JP-36
# 40        Metropolis   NA  JP.TK  JP-13
# 41        Prefecture   NA  JP.TT  JP-31
# 42        Prefecture   NA  JP.TY  JP-16
# 43        Prefecture   NA  JP.WK  JP-30
# 44        Prefecture   NA  JP.YT  JP-06
# 45        Prefecture   NA  JP.YC  JP-35
# 46        Prefecture   NA  JP.YN  JP-19
#
#                                              geometry
# 0   MULTIPOLYGON (((137.09743 34.65121, 137.09773 ...
# 1   MULTIPOLYGON (((140.70844 38.92136, 140.69861 ...
# 2   MULTIPOLYGON (((140.95625 40.27003, 140.95795 ...
# 3   MULTIPOLYGON (((139.82417 34.91861, 139.82465 ...
# 4   MULTIPOLYGON (((132.56189 32.91159, 132.56241 ...
# 5   MULTIPOLYGON (((135.77737 35.36200, 135.77370 ...
# 6   MULTIPOLYGON (((130.88498 33.18366, 130.88748 ...
# 7   MULTIPOLYGON (((140.26530 36.93347, 140.26071 ...
# 8   POLYGON ((136.67628 35.17009, 136.67532 35.165...
# 9   POLYGON ((138.94455 36.09058, 138.94102 36.088...
# 10  MULTIPOLYGON (((132.48229 34.03756, 132.48244 ...
# 11  MULTIPOLYGON (((140.08817 41.41789, 140.08797 ...
# 12  MULTIPOLYGON (((134.82556 34.17766, 134.82603 ...
# 13  MULTIPOLYGON (((140.12048 35.87258, 140.11476 ...
# 14  MULTIPOLYGON (((136.32423 36.23103, 136.31923 ...
# 15  MULTIPOLYGON (((140.78009 39.00500, 140.78273 ...
# 16  MULTIPOLYGON (((133.67378 34.01981, 133.67302 ...
# 17  MULTIPOLYGON (((128.43611 27.06694, 128.43639 ...
# 18  MULTIPOLYGON (((139.61749 35.13664, 139.61778 ...
# 19  MULTIPOLYGON (((132.55528 32.74778, 132.55640 ...
# 20  MULTIPOLYGON (((130.15639 32.08806, 130.15805 ...
# 21  POLYGON ((135.95520 34.84940, 135.96448 34.850...
# 22  MULTIPOLYGON (((136.03195 33.77222, 136.03195 ...
# 23  MULTIPOLYGON (((140.68266 37.83328, 140.68584 ...
# 24  MULTIPOLYGON (((131.37886 31.45302, 131.37869 ...
# 25  POLYGON ((138.36853 35.96162, 138.36444 35.958...
# 26  MULTIPOLYGON (((129.78648 32.56644, 129.78696 ...
# 27  POLYGON ((135.89703 33.93872, 135.89961 33.931...
# 28  MULTIPOLYGON (((138.36601 36.94147, 138.36581 ...
# 29  MULTIPOLYGON (((131.92894 32.72650, 131.92938 ...
# 30  MULTIPOLYGON (((133.53778 34.30429, 133.53766 ...
# 31  MULTIPOLYGON (((123.79430 24.07097, 123.79513 ...
# 32  MULTIPOLYGON (((135.20668 34.28478, 135.19842 ...
# 33  MULTIPOLYGON (((130.04959 32.99534, 130.04607 ...
# 34  POLYGON ((139.82547 35.79621, 139.82352 35.800...
# 35  POLYGON ((136.01706 34.79412, 136.01799 34.805...
# 36  MULTIPOLYGON (((132.03995 34.46294, 132.03778 ...
# 37  MULTIPOLYGON (((137.56377 34.69604, 137.56377 ...
# 38  POLYGON ((139.75496 36.21013, 139.75264 36.208...
# 39  MULTIPOLYGON (((134.32611 33.55667, 134.32666 ...
# 40  MULTIPOLYGON (((141.46501 24.24473, 141.46501 ...
# 41  MULTIPOLYGON (((133.25102 35.07544, 133.23483 ...
# 42  POLYGON ((137.05212 36.34285, 137.05505 36.333...
# 43  MULTIPOLYGON (((135.82005 33.44973, 135.82001 ...
# 44  MULTIPOLYGON (((140.27187 37.87292, 140.27295 ...
# 45  MULTIPOLYGON (((132.49124 33.73628, 132.49110 ...
# 46  POLYGON ((138.53334 35.35424, 138.53340 35.343...

# %%
# fix NA

iso_1_replacements = {
    12: 'JP-28',  # Replace 'NA' with 'JP-28' for index 12
    26: 'JP-42',  # Replace 'NA' with 'JP-42' for index 26
}

# Fill NA values in ISO_1 column based on the dictionary
for index, iso_code in iso_1_replacements.items():
    japan_shp.at[index, 'ISO_1'] = iso_code

# %%
def convert_iso_to_region_code(iso_code):
    if '-' in iso_code:
        numeric_part = iso_code.split('-')[1]
        # Convert to the format XX000
        region_code = numeric_part + '000'
    else:
        # Handle unexpected formats
        region_code = '00000'
    return region_code

# Apply the conversion function to the ISO_1 column and create the REGION_CODE column
japan_shp['REGION_CODE'] = japan_shp['ISO_1'].apply(convert_iso_to_region_code)

# %% [markdown]
# ## Select column

# %%
japan_map = japan_shp[['NAME_1', 'REGION_CODE', 'geometry']]
japan_map
# Out:
#        NAME_1 REGION_CODE                                           geometry
# 0       Aichi       23000  MULTIPOLYGON (((137.09743 34.65121, 137.09773 ...
# 1       Akita       05000  MULTIPOLYGON (((140.70844 38.92136, 140.69861 ...
# 2      Aomori       02000  MULTIPOLYGON (((140.95625 40.27003, 140.95795 ...
# 3       Chiba       12000  MULTIPOLYGON (((139.82417 34.91861, 139.82465 ...
# 4       Ehime       38000  MULTIPOLYGON (((132.56189 32.91159, 132.56241 ...
# 5       Fukui       18000  MULTIPOLYGON (((135.77737 35.36200, 135.77370 ...
# 6     Fukuoka       40000  MULTIPOLYGON (((130.88498 33.18366, 130.88748 ...
# 7   Fukushima       07000  MULTIPOLYGON (((140.26530 36.93347, 140.26071 ...
# 8        Gifu       21000  POLYGON ((136.67628 35.17009, 136.67532 35.165...
# 9       Gunma       10000  POLYGON ((138.94455 36.09058, 138.94102 36.088...
# 10  Hiroshima       34000  MULTIPOLYGON (((132.48229 34.03756, 132.48244 ...
# 11   Hokkaido       01000  MULTIPOLYGON (((140.08817 41.41789, 140.08797 ...
# 12      Hyōgo       28000  MULTIPOLYGON (((134.82556 34.17766, 134.82603 ...
# 13    Ibaraki       08000  MULTIPOLYGON (((140.12048 35.87258, 140.11476 ...
# 14   Ishikawa       17000  MULTIPOLYGON (((136.32423 36.23103, 136.31923 ...
# 15      Iwate       03000  MULTIPOLYGON (((140.78009 39.00500, 140.78273 ...
# 16     Kagawa       37000  MULTIPOLYGON (((133.67378 34.01981, 133.67302 ...
# 17  Kagoshima       46000  MULTIPOLYGON (((128.43611 27.06694, 128.43639 ...
# 18   Kanagawa       14000  MULTIPOLYGON (((139.61749 35.13664, 139.61778 ...
# 19      Kochi       39000  MULTIPOLYGON (((132.55528 32.74778, 132.55640 ...
# 20   Kumamoto       43000  MULTIPOLYGON (((130.15639 32.08806, 130.15805 ...
# 21      Kyoto       26000  POLYGON ((135.95520 34.84940, 135.96448 34.850...
# 22        Mie       24000  MULTIPOLYGON (((136.03195 33.77222, 136.03195 ...
# 23     Miyagi       04000  MULTIPOLYGON (((140.68266 37.83328, 140.68584 ...
# 24   Miyazaki       45000  MULTIPOLYGON (((131.37886 31.45302, 131.37869 ...
# 25     Nagano       20000  POLYGON ((138.36853 35.96162, 138.36444 35.958...
# 26   Naoasaki       42000  MULTIPOLYGON (((129.78648 32.56644, 129.78696 ...
# 27       Nara       29000  POLYGON ((135.89703 33.93872, 135.89961 33.931...
# 28    Niigata       15000  MULTIPOLYGON (((138.36601 36.94147, 138.36581 ...
# 29       Oita       44000  MULTIPOLYGON (((131.92894 32.72650, 131.92938 ...
# 30    Okayama       33000  MULTIPOLYGON (((133.53778 34.30429, 133.53766 ...
# 31    Okinawa       47000  MULTIPOLYGON (((123.79430 24.07097, 123.79513 ...
# 32      Osaka       27000  MULTIPOLYGON (((135.20668 34.28478, 135.19842 ...
# 33       Saga       41000  MULTIPOLYGON (((130.04959 32.99534, 130.04607 ...
# 34    Saitama       11000  POLYGON ((139.82547 35.79621, 139.82352 35.800...
# 35      Shiga       25000  POLYGON ((136.01706 34.79412, 136.01799 34.805...
# 36    Shimane       32000  MULTIPOLYGON (((132.03995 34.46294, 132.03778 ...
# 37   Shizuoka       22000  MULTIPOLYGON (((137.56377 34.69604, 137.56377 ...
# 38    Tochigi       09000  POLYGON ((139.75496 36.21013, 139.75264 36.208...
# 39  Tokushima       36000  MULTIPOLYGON (((134.32611 33.55667, 134.32666 ...
# 40      Tokyo       13000  MULTIPOLYGON (((141.46501 24.24473, 141.46501 ...
# 41    Tottori       31000  MULTIPOLYGON (((133.25102 35.07544, 133.23483 ...
# 42     Toyama       16000  POLYGON ((137.05212 36.34285, 137.05505 36.333...
# 43   Wakayama       30000  MULTIPOLYGON (((135.82005 33.44973, 135.82001 ...
# 44   Yamagata       06000  MULTIPOLYGON (((140.27187 37.87292, 140.27295 ...
# 45  Yamaguchi       35000  MULTIPOLYGON (((132.49124 33.73628, 132.49110 ...
# 46  Yamanashi       19000  POLYGON ((138.53334 35.35424, 138.53340 35.343...

# %%
m = japan_map.explore()
m

# %% [markdown]
# ## Hospital per area

# %%
df_city_area = pd.read_csv('data/city_area.csv')
df_hospital_clinic_number = pd.read_csv('data/hospital_clinic_number.csv')

# %%
# convert ha to km2
df_city_area['area_number'] = df_city_area['Total land area (Incl. the northern territories and Takeshima)【ha】'] / 100

# Filter the data for the year 2022 and exclude the "Japan" region
df_city_area = df_city_area[(df_city_area["Time"] == 2022) & (df_city_area["Region"] != "Japan")]

df_city_area.head()
# Out:
#       Time  Region Code      Region  \
# 2257  2022         1000    Hokkaido
# 2258  2022         2000  Aomori-ken
# 2259  2022         3000   Iwate-ken
# 2260  2022         4000  Miyagi-ken
# 2261  2022         5000   Akita-ken
#
#       Total land area (Incl. the northern territories and Takeshima)【ha】  \
# 2257                                            8342381
# 2258                                             964595
# 2259                                            1527501
# 2260                                             728229
# 2261                                            1163752
#
#       Annotation  area_number
# 2257         NaN     83423.81
# 2258         NaN      9645.95
# 2259         NaN     15275.01
# 2260         NaN      7282.29
# 2261         NaN     11637.52

# %%
def clean_area_name(area_name):
    """Remove specific suffixes from area names and strip whitespace."""
    suffixes = ['-ken', '-fu', '-to', '-do']
    for suffix in suffixes:
        area_name = area_name.replace(suffix, '')
    return area_name.strip()

# Create a dictionary for the specific mismatched area names corrections
area_corrections = {
    'Gumma': 'Gunma',
    'Hyogo': 'Hyōgo',
    'Nagasaki': 'Naoasaki'
}

df_city_area = df_city_area.rename(columns={'Region': 'NAME_1'})
df_city_area.loc[:, 'NAME_1'] = df_city_area['NAME_1'].apply(clean_area_name)
df_city_area.loc[:, 'NAME_1'] = df_city_area['NAME_1'].replace(area_corrections)
df_city_area
# Out:
#       Time  Region Code     NAME_1  \
# 2257  2022         1000   Hokkaido
# 2258  2022         2000     Aomori
# 2259  2022         3000      Iwate
# 2260  2022         4000     Miyagi
# 2261  2022         5000      Akita
# 2262  2022         6000   Yamagata
# 2263  2022         7000  Fukushima
# 2264  2022         8000    Ibaraki
# 2265  2022         9000    Tochigi
# 2266  2022        10000      Gunma
# 2267  2022        11000    Saitama
# 2268  2022        12000      Chiba
# 2269  2022        13000      Tokyo
# 2270  2022        14000   Kanagawa
# 2271  2022        15000    Niigata
# 2272  2022        16000     Toyama
# 2273  2022        17000   Ishikawa
# 2274  2022        18000      Fukui
# 2275  2022        19000  Yamanashi
# 2276  2022        20000     Nagano
# 2277  2022        21000       Gifu
# 2278  2022        22000   Shizuoka
# 2279  2022        23000      Aichi
# 2280  2022        24000        Mie
# 2281  2022        25000      Shiga
# 2282  2022        26000      Kyoto
# 2283  2022        27000      Osaka
# 2284  2022        28000      Hyōgo
# 2285  2022        29000       Nara
# 2286  2022        30000   Wakayama
# 2287  2022        31000    Tottori
# 2288  2022        32000    Shimane
# 2289  2022        33000    Okayama
# 2290  2022        34000  Hiroshima
# 2291  2022        35000  Yamaguchi
# 2292  2022        36000  Tokushima
# 2293  2022        37000     Kagawa
# 2294  2022        38000      Ehime
# 2295  2022        39000      Kochi
# 2296  2022        40000    Fukuoka
# 2297  2022        41000       Saga
# 2298  2022        42000   Naoasaki
# 2299  2022        43000   Kumamoto
# 2300  2022        44000       Oita
# 2301  2022        45000   Miyazaki
# 2302  2022        46000  Kagoshima
# 2303  2022        47000    Okinawa
#
#       Total land area (Incl. the northern territories and Takeshima)【ha】  \
# 2257                                            8342381
# 2258                                             964595
# 2259                                            1527501
# 2260                                             728229
# 2261                                            1163752
# 2262                                             932315
# 2263                                            1378414
# 2264                                             609754
# 2265                                             640809
# 2266                                             636228
# 2267                                             379775
# 2268                                             515674
# 2269                                             219405
# 2270                                             241632
# 2271                                            1258396
# 2272                                             424754
# 2273                                             418623
# 2274                                             419058
# 2275                                             446527
# 2276                                            1356156
# 2277                                            1062129
# 2278                                             777702
# 2279                                             517324
# 2280                                             577448
# 2281                                             401738
# 2282                                             461220
# 2283                                             190534
# 2284                                             840094
# 2285                                             369094
# 2286                                             472469
# 2287                                             350713
# 2288                                             670786
# 2289                                             711477
# 2290                                             847900
# 2291                                             611250
# 2292                                             414699
# 2293                                             187691
# 2294                                             567598
# 2295                                             710291
# 2296                                             498764
# 2297                                             244067
# 2298                                             413099
# 2299                                             740918
# 2300                                             634070
# 2301                                             773424
# 2302                                             918633
# 2303                                             228215
#
#       Annotation  area_number
# 2257         NaN     83423.81
# 2258         NaN      9645.95
# 2259         NaN     15275.01
# 2260         NaN      7282.29
# 2261         NaN     11637.52
# 2262         NaN      9323.15
# 2263         NaN     13784.14
# 2264         NaN      6097.54
# 2265         NaN      6408.09
# 2266         NaN      6362.28
# 2267         NaN      3797.75
# 2268         NaN      5156.74
# 2269         NaN      2194.05
# 2270         NaN      2416.32
# 2271         NaN     12583.96
# 2272         NaN      4247.54
# 2273         NaN      4186.23
# 2274         NaN      4190.58
# 2275         NaN      4465.27
# 2276         NaN     13561.56
# 2277         NaN     10621.29
# 2278         NaN      7777.02
# 2279         NaN      5173.24
# 2280         NaN      5774.48
# 2281         NaN      4017.38
# 2282         NaN      4612.20
# 2283         NaN      1905.34
# 2284         NaN      8400.94
# 2285         NaN      3690.94
# 2286         NaN      4724.69
# 2287         NaN      3507.13
# 2288         NaN      6707.86
# 2289         NaN      7114.77
# 2290         NaN      8479.00
# 2291         NaN      6112.50
# 2292         NaN      4146.99
# 2293         NaN      1876.91
# 2294         NaN      5675.98
# 2295         NaN      7102.91
# 2296         NaN      4987.64
# 2297         NaN      2440.67
# 2298         NaN      4130.99
# 2299         NaN      7409.18
# 2300         NaN      6340.70
# 2301         NaN      7734.24
# 2302         NaN      9186.33
# 2303         NaN      2282.15

# %%
df_hospital_clinic_number = df_hospital_clinic_number.rename(columns={'AREA': 'NAME_1'})
df_hospital_clinic_number.head()
# Out:
#    Unnamed: 0    NAME_1  NUMBER
# 0           1  Hokkaido     144
# 1           2    Aomori      25
# 2           3     Iwate      25
# 3           4    Miyagi      41
# 4           5     Akita      25

# %%
# Merge the datasets on AREA
merged_data = pd.merge(df_city_area, df_hospital_clinic_number, on='NAME_1', how='inner')

# Calculate the ratio
merged_data['area_ratio'] = merged_data['NUMBER'] / merged_data['area_number']

# Select only the relevant columns for the final dataframe
df_hospital_area_ratio = merged_data[['NAME_1', 'Region Code', 'area_ratio']]
df_hospital_area_ratio.head()
# Out:
#      NAME_1  Region Code  area_ratio
# 0  Hokkaido         1000    0.001726
# 1    Aomori         2000    0.002592
# 2     Iwate         3000    0.001637
# 3    Miyagi         4000    0.005630
# 4     Akita         5000    0.002148

# %%
japan_map['REGION_CODE'] = japan_map['REGION_CODE'].astype(int)
df_hospital_area_ratio['Region Code'] = df_hospital_area_ratio['Region Code'].astype(int)

# Perform the merge operation
japan_area_hospital = pd.merge(japan_map, df_hospital_area_ratio[['Region Code', 'area_ratio']], 
                     left_on='REGION_CODE', 
                     right_on='Region Code', 
                     how='left')

japan_area_hospital.drop(columns=['Region Code'], inplace=True)
# Out:
# /Users/tongfah/anaconda3/envs/Internship_japan/lib/python3.8/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /var/folders/n6/98dby4495lj_l5nmsm3lyr_40000gn/T/ipykernel_78416/2957339683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hospital_area_ratio['Region Code'] = df_hospital_area_ratio['Region Code'].astype(int)

# %%
japan_area_hospital
# Out:
#        NAME_1  REGION_CODE                                           geometry  \
# 0       Aichi        23000  MULTIPOLYGON (((137.09743 34.65121, 137.09773 ...
# 1       Akita         5000  MULTIPOLYGON (((140.70844 38.92136, 140.69861 ...
# 2      Aomori         2000  MULTIPOLYGON (((140.95625 40.27003, 140.95795 ...
# 3       Chiba        12000  MULTIPOLYGON (((139.82417 34.91861, 139.82465 ...
# 4       Ehime        38000  MULTIPOLYGON (((132.56189 32.91159, 132.56241 ...
# 5       Fukui        18000  MULTIPOLYGON (((135.77737 35.36200, 135.77370 ...
# 6     Fukuoka        40000  MULTIPOLYGON (((130.88498 33.18366, 130.88748 ...
# 7   Fukushima         7000  MULTIPOLYGON (((140.26530 36.93347, 140.26071 ...
# 8        Gifu        21000  POLYGON ((136.67628 35.17009, 136.67532 35.165...
# 9       Gunma        10000  POLYGON ((138.94455 36.09058, 138.94102 36.088...
# 10  Hiroshima        34000  MULTIPOLYGON (((132.48229 34.03756, 132.48244 ...
# 11   Hokkaido         1000  MULTIPOLYGON (((140.08817 41.41789, 140.08797 ...
# 12      Hyōgo        28000  MULTIPOLYGON (((134.82556 34.17766, 134.82603 ...
# 13    Ibaraki         8000  MULTIPOLYGON (((140.12048 35.87258, 140.11476 ...
# 14   Ishikawa        17000  MULTIPOLYGON (((136.32423 36.23103, 136.31923 ...
# 15      Iwate         3000  MULTIPOLYGON (((140.78009 39.00500, 140.78273 ...
# 16     Kagawa        37000  MULTIPOLYGON (((133.67378 34.01981, 133.67302 ...
# 17  Kagoshima        46000  MULTIPOLYGON (((128.43611 27.06694, 128.43639 ...
# 18   Kanagawa        14000  MULTIPOLYGON (((139.61749 35.13664, 139.61778 ...
# 19      Kochi        39000  MULTIPOLYGON (((132.55528 32.74778, 132.55640 ...
# 20   Kumamoto        43000  MULTIPOLYGON (((130.15639 32.08806, 130.15805 ...
# 21      Kyoto        26000  POLYGON ((135.95520 34.84940, 135.96448 34.850...
# 22        Mie        24000  MULTIPOLYGON (((136.03195 33.77222, 136.03195 ...
# 23     Miyagi         4000  MULTIPOLYGON (((140.68266 37.83328, 140.68584 ...
# 24   Miyazaki        45000  MULTIPOLYGON (((131.37886 31.45302, 131.37869 ...
# 25     Nagano        20000  POLYGON ((138.36853 35.96162, 138.36444 35.958...
# 26   Naoasaki        42000  MULTIPOLYGON (((129.78648 32.56644, 129.78696 ...
# 27       Nara        29000  POLYGON ((135.89703 33.93872, 135.89961 33.931...
# 28    Niigata        15000  MULTIPOLYGON (((138.36601 36.94147, 138.36581 ...
# 29       Oita        44000  MULTIPOLYGON (((131.92894 32.72650, 131.92938 ...
# 30    Okayama        33000  MULTIPOLYGON (((133.53778 34.30429, 133.53766 ...
# 31    Okinawa        47000  MULTIPOLYGON (((123.79430 24.07097, 123.79513 ...
# 32      Osaka        27000  MULTIPOLYGON (((135.20668 34.28478, 135.19842 ...
# 33       Saga        41000  MULTIPOLYGON (((130.04959 32.99534, 130.04607 ...
# 34    Saitama        11000  POLYGON ((139.82547 35.79621, 139.82352 35.800...
# 35      Shiga        25000  POLYGON ((136.01706 34.79412, 136.01799 34.805...
# 36    Shimane        32000  MULTIPOLYGON (((132.03995 34.46294, 132.03778 ...
# 37   Shizuoka        22000  MULTIPOLYGON (((137.56377 34.69604, 137.56377 ...
# 38    Tochigi         9000  POLYGON ((139.75496 36.21013, 139.75264 36.208...
# 39  Tokushima        36000  MULTIPOLYGON (((134.32611 33.55667, 134.32666 ...
# 40      Tokyo        13000  MULTIPOLYGON (((141.46501 24.24473, 141.46501 ...
# 41    Tottori        31000  MULTIPOLYGON (((133.25102 35.07544, 133.23483 ...
# 42     Toyama        16000  POLYGON ((137.05212 36.34285, 137.05505 36.333...
# 43   Wakayama        30000  MULTIPOLYGON (((135.82005 33.44973, 135.82001 ...
# 44   Yamagata         6000  MULTIPOLYGON (((140.27187 37.87292, 140.27295 ...
# 45  Yamaguchi        35000  MULTIPOLYGON (((132.49124 33.73628, 132.49110 ...
# 46  Yamanashi        19000  POLYGON ((138.53334 35.35424, 138.53340 35.343...
#
#     area_ratio
# 0     0.020877
# 1     0.002148
# 2     0.002592
# 3     0.017453
# 4     0.006871
# 5     0.009068
# 6     0.032280
# 7     0.004208
# 8     0.003201
# 9     0.005816
# 10    0.006605
# 11    0.001726
# 12    0.011784
# 13    0.012136
# 14    0.008361
# 15    0.001637
# 16    0.015984
# 17    0.008164
# 18    0.049662
# 19    0.008588
# 20    0.010932
# 21    0.016695
# 22    0.005022
# 23    0.005630
# 24    0.004913
# 25    0.003392
# 26    0.015735
# 27    0.006231
# 28    0.001589
# 29    0.010882
# 30    0.006465
# 31    0.016651
# 32    0.077676
# 33    0.017618
# 34    0.027385
# 35    0.006721
# 36    0.001491
# 37    0.006686
# 38    0.006086
# 39    0.010128
# 40    0.081129
# 41    0.003136
# 42    0.004238
# 43    0.005926
# 44    0.001609
# 45    0.008180
# 46    0.004031

# %%
m = japan_area_hospital.explore('area_ratio', cmap='Purples')
m

# %% [markdown]
# ## Ratio of Lung Cancer to japan population

# %%
df_population = pd.read_csv('data/japanese_population.csv')
df_lung_cancer = pd.read_csv('data/lung_cancer.csv')

# %%
# Filter the population data for the year 2023 and exclude the "Japan" region
population = df_population[(df_population["Time"] == '2023') & (df_population["Region"] != "Japan")]

# Ensure the columns are of integer type
population['Total population (Both sexes)【person】'] = population['Total population (Both sexes)【person】'].astype(int)
population = population.rename(columns={'Region': 'AREA'})

# Process lung cancer data
df_lung_cancer['NUMBER'] = df_lung_cancer['NUMBER'].str.replace(',', '').astype(int)

# Merge the datasets on AREA
merged_data = pd.merge(population, df_lung_cancer, on='AREA', how='inner')

# Calculate the ratio
merged_data['Lung Cancer Ratio'] = merged_data['NUMBER'] / merged_data['Total population (Both sexes)【person】']

# Select only the relevant columns for the final dataframe
df_population_ratio = merged_data[['AREA', 'Region Code',  'Lung Cancer Ratio']]
# Out:
# /var/folders/n6/98dby4495lj_l5nmsm3lyr_40000gn/T/ipykernel_78416/213280744.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['Total population (Both sexes)【person】'] = population['Total population (Both sexes)【person】'].astype(int)

# %%
df_population_ratio = df_population_ratio.rename(columns={'AREA': 'NAME_1', 'Region Code':'REGION_CODE', 'Lung Cancer Ratio':'lung_cancer_ratio'})
df_population_ratio
# Out:
#            NAME_1  REGION_CODE  lung_cancer_ratio
# 0        Hokkaido         1000           0.000162
# 1      Aomori-ken         2000           0.000209
# 2       Iwate-ken         3000           0.000202
# 3      Miyagi-ken         4000           0.000213
# 4       Akita-ken         5000           0.000210
# 5    Yamagata-ken         6000           0.000245
# 6   Fukushima-ken         7000           0.000206
# 7     Ibaraki-ken         8000           0.000175
# 8     Tochigi-ken         9000           0.000197
# 9       Gumma-ken        10000           0.000195
# 10    Saitama-ken        11000           0.000179
# 11      Chiba-ken        12000           0.000165
# 12       Tokyo-to        13000           0.000174
# 13   Kanagawa-ken        14000           0.000181
# 14    Niigata-ken        15000           0.000218
# 15     Toyama-ken        16000           0.000220
# 16   Ishikawa-ken        17000           0.000199
# 17      Fukui-ken        18000           0.000198
# 18  Yamanashi-ken        19000           0.000204
# 19     Nagano-ken        20000           0.000187
# 20       Gifu-ken        21000           0.000185
# 21   Shizuoka-ken        22000           0.000191
# 22      Aichi-ken        23000           0.000181
# 23        Mie-ken        24000           0.000177
# 24      Shiga-ken        25000           0.000176
# 25       Kyoto-fu        26000           0.000151
# 26       Osaka-fu        27000           0.000155
# 27      Hyogo-ken        28000           0.000162
# 28       Nara-ken        29000           0.000161
# 29   Wakayama-ken        30000           0.000150
# 30    Tottori-ken        31000           0.000197
# 31    Shimane-ken        32000           0.000212
# 32    Okayama-ken        33000           0.000200
# 33  Hiroshima-ken        34000           0.000176
# 34  Yamaguchi-ken        35000           0.000169
# 35  Tokushima-ken        36000           0.000174
# 36     Kagawa-ken        37000           0.000199
# 37      Ehime-ken        38000           0.000175
# 38      Kochi-ken        39000           0.000188
# 39    Fukuoka-ken        40000           0.000161
# 40       Saga-ken        41000           0.000174
# 41   Nagasaki-ken        42000           0.000155
# 42   Kumamoto-ken        43000           0.000176
# 43       Oita-ken        44000           0.000186
# 44   Miyazaki-ken        45000           0.000174
# 45  Kagoshima-ken        46000           0.000170
# 46    Okinawa-ken        47000           0.000133

# %%
japan_map['REGION_CODE'] = japan_map['REGION_CODE'].astype(int)
df_population_ratio['REGION_CODE'] = df_population_ratio['REGION_CODE'].astype(int)

# Perform the merge operation
japan_population_ratio = pd.merge(japan_map, df_population_ratio[['REGION_CODE', 'lung_cancer_ratio']],
                               left_on='REGION_CODE',
                               right_on='REGION_CODE',
                               how='left')
# Out:
# /Users/tongfah/anaconda3/envs/Internship_japan/lib/python3.8/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
japan_population_ratio
# Out:
#        NAME_1  REGION_CODE                                           geometry  \
# 0       Aichi        23000  MULTIPOLYGON (((137.09743 34.65121, 137.09773 ...
# 1       Akita         5000  MULTIPOLYGON (((140.70844 38.92136, 140.69861 ...
# 2      Aomori         2000  MULTIPOLYGON (((140.95625 40.27003, 140.95795 ...
# 3       Chiba        12000  MULTIPOLYGON (((139.82417 34.91861, 139.82465 ...
# 4       Ehime        38000  MULTIPOLYGON (((132.56189 32.91159, 132.56241 ...
# 5       Fukui        18000  MULTIPOLYGON (((135.77737 35.36200, 135.77370 ...
# 6     Fukuoka        40000  MULTIPOLYGON (((130.88498 33.18366, 130.88748 ...
# 7   Fukushima         7000  MULTIPOLYGON (((140.26530 36.93347, 140.26071 ...
# 8        Gifu        21000  POLYGON ((136.67628 35.17009, 136.67532 35.165...
# 9       Gunma        10000  POLYGON ((138.94455 36.09058, 138.94102 36.088...
# 10  Hiroshima        34000  MULTIPOLYGON (((132.48229 34.03756, 132.48244 ...
# 11   Hokkaido         1000  MULTIPOLYGON (((140.08817 41.41789, 140.08797 ...
# 12      Hyōgo        28000  MULTIPOLYGON (((134.82556 34.17766, 134.82603 ...
# 13    Ibaraki         8000  MULTIPOLYGON (((140.12048 35.87258, 140.11476 ...
# 14   Ishikawa        17000  MULTIPOLYGON (((136.32423 36.23103, 136.31923 ...
# 15      Iwate         3000  MULTIPOLYGON (((140.78009 39.00500, 140.78273 ...
# 16     Kagawa        37000  MULTIPOLYGON (((133.67378 34.01981, 133.67302 ...
# 17  Kagoshima        46000  MULTIPOLYGON (((128.43611 27.06694, 128.43639 ...
# 18   Kanagawa        14000  MULTIPOLYGON (((139.61749 35.13664, 139.61778 ...
# 19      Kochi        39000  MULTIPOLYGON (((132.55528 32.74778, 132.55640 ...
# 20   Kumamoto        43000  MULTIPOLYGON (((130.15639 32.08806, 130.15805 ...
# 21      Kyoto        26000  POLYGON ((135.95520 34.84940, 135.96448 34.850...
# 22        Mie        24000  MULTIPOLYGON (((136.03195 33.77222, 136.03195 ...
# 23     Miyagi         4000  MULTIPOLYGON (((140.68266 37.83328, 140.68584 ...
# 24   Miyazaki        45000  MULTIPOLYGON (((131.37886 31.45302, 131.37869 ...
# 25     Nagano        20000  POLYGON ((138.36853 35.96162, 138.36444 35.958...
# 26   Naoasaki        42000  MULTIPOLYGON (((129.78648 32.56644, 129.78696 ...
# 27       Nara        29000  POLYGON ((135.89703 33.93872, 135.89961 33.931...
# 28    Niigata        15000  MULTIPOLYGON (((138.36601 36.94147, 138.36581 ...
# 29       Oita        44000  MULTIPOLYGON (((131.92894 32.72650, 131.92938 ...
# 30    Okayama        33000  MULTIPOLYGON (((133.53778 34.30429, 133.53766 ...
# 31    Okinawa        47000  MULTIPOLYGON (((123.79430 24.07097, 123.79513 ...
# 32      Osaka        27000  MULTIPOLYGON (((135.20668 34.28478, 135.19842 ...
# 33       Saga        41000  MULTIPOLYGON (((130.04959 32.99534, 130.04607 ...
# 34    Saitama        11000  POLYGON ((139.82547 35.79621, 139.82352 35.800...
# 35      Shiga        25000  POLYGON ((136.01706 34.79412, 136.01799 34.805...
# 36    Shimane        32000  MULTIPOLYGON (((132.03995 34.46294, 132.03778 ...
# 37   Shizuoka        22000  MULTIPOLYGON (((137.56377 34.69604, 137.56377 ...
# 38    Tochigi         9000  POLYGON ((139.75496 36.21013, 139.75264 36.208...
# 39  Tokushima        36000  MULTIPOLYGON (((134.32611 33.55667, 134.32666 ...
# 40      Tokyo        13000  MULTIPOLYGON (((141.46501 24.24473, 141.46501 ...
# 41    Tottori        31000  MULTIPOLYGON (((133.25102 35.07544, 133.23483 ...
# 42     Toyama        16000  POLYGON ((137.05212 36.34285, 137.05505 36.333...
# 43   Wakayama        30000  MULTIPOLYGON (((135.82005 33.44973, 135.82001 ...
# 44   Yamagata         6000  MULTIPOLYGON (((140.27187 37.87292, 140.27295 ...
# 45  Yamaguchi        35000  MULTIPOLYGON (((132.49124 33.73628, 132.49110 ...
# 46  Yamanashi        19000  POLYGON ((138.53334 35.35424, 138.53340 35.343...
#
#     lung_cancer_ratio
# 0            0.000181
# 1            0.000210
# 2            0.000209
# 3            0.000165
# 4            0.000175
# 5            0.000198
# 6            0.000161
# 7            0.000206
# 8            0.000185
# 9            0.000195
# 10           0.000176
# 11           0.000162
# 12           0.000162
# 13           0.000175
# 14           0.000199
# 15           0.000202
# 16           0.000199
# 17           0.000170
# 18           0.000181
# 19           0.000188
# 20           0.000176
# 21           0.000151
# 22           0.000177
# 23           0.000213
# 24           0.000174
# 25           0.000187
# 26           0.000155
# 27           0.000161
# 28           0.000218
# 29           0.000186
# 30           0.000200
# 31           0.000133
# 32           0.000155
# 33           0.000174
# 34           0.000179
# 35           0.000176
# 36           0.000212
# 37           0.000191
# 38           0.000197
# 39           0.000174
# 40           0.000174
# 41           0.000197
# 42           0.000220
# 43           0.000150
# 44           0.000245
# 45           0.000169
# 46           0.000204

# %%
m = japan_population_ratio.explore('lung_cancer_ratio', cmap='Wistia')
m
